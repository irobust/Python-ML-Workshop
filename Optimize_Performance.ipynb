# %% [markdown]
# # Optimize Performance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
data = load_breast_cancer(as_frame=True)

X = data.frame[data.feature_names]
y = data["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((398, 30), (171, 30))

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=1)
model.fit(X_train, y_train)

test_scores = model.score(X_test, y_test)
test_scores
# Out:
# 0.9707602339181286

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(model, X_train, y_train, cv=5)
cv_scores.mean()
# Out:
# np.float64(0.949746835443038)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "n_estimators": [x for x in range(50,151,50)],
    "max_depth": [None] + [x for x in range(3,11)]
}

grid_search = GridSearchCV(
    estimator = RandomForestClassifier(random_state=42),
    param_grid = param_grid,
    cv      = 5,
    n_jobs  = 1,
    scoring = "accuracy"
)

grid_search
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=1,
#              param_grid={'max_depth': [None, 3, 4, 5, 6, 7, 8, 9, 10],
#                          'n_estimators': [50, 100, 150]},
#              scoring='accuracy')

# %%
grid_search.fit(X_train, y_train)

grid_search.best_params_, grid_search.best_score_, grid_search.best_estimator_
# Out:
# ({'max_depth': 6, 'n_estimators': 150},
#  np.float64(0.9572151898734177),
#  RandomForestClassifier(max_depth=6, n_estimators=150, random_state=42))

# %%
best_model = grid_search.best_estimator_
best_model_test_score = best_model.score(X_test, y_test)
best_model_test_score
# Out:
# 0.9707602339181286

# %%
df = pd.DataFrame(grid_search.cv_results_)
df = df.sort_values("mean_test_score", ascending=False)
df.head(5)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 14       0.542202      0.027445         0.020236        0.001990
# 7        0.658179      0.207480         0.029633        0.014144
# 6        0.300592      0.110662         0.018449        0.007728
# 11       0.339911      0.009232         0.012721        0.000410
# 17       0.346599      0.008028         0.013222        0.000280
#
#    param_max_depth  param_n_estimators                                 params  \
# 14               6                 150  {'max_depth': 6, 'n_estimators': 150}
# 7                4                 100  {'max_depth': 4, 'n_estimators': 100}
# 6                4                  50   {'max_depth': 4, 'n_estimators': 50}
# 11               5                 150  {'max_depth': 5, 'n_estimators': 150}
# 17               7                 150  {'max_depth': 7, 'n_estimators': 150}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 14             0.9750               0.95             0.9750
# 7              0.9375               0.95             0.9625
# 6              0.9500               0.95             0.9625
# 11             0.9500               0.95             0.9625
# 17             0.9500               0.95             0.9750
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 14           0.949367           0.936709         0.957215        0.015276
# 7            0.949367           0.962025         0.952278        0.009290
# 6            0.949367           0.949367         0.952247        0.005134
# 11           0.949367           0.949367         0.952247        0.005134
# 17           0.949367           0.936709         0.952215        0.012470
#
#     rank_test_score
# 14                1
# 7                 2
# 6                 3
# 11                3
# 17                5
