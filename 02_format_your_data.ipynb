# %% [markdown]
# # 02 Format your data for modeling
#
# This notebook shows five quick formatting steps that turn a small email dataset into numeric features ready for scikit-learn.

# %% [markdown]
# ## Create a sample email dataset

# %%
import pandas as pd
import numpy as np
import sklearn

data = {
    "subject": [
        "Win a free vacation",
        "Your receipt from Bookstore",
        "Limited time offer",
        "Meeting agenda",
        "Update your account info",
        "Family photos inside",
        "Exclusive promo just for you",
        "Weekly project status"
    ],
    "label": [
        "spam",
        "not_spam",
        "spam",
        "not_spam",
        "spam",
        "not_spam",
        "spam",
        "not_spam"
    ],
    "sender_domain": [
        "promos.biz",
        "gmail.com",
        "offers.mail",
        "company.com",
        "alerts.bank",
        "yahoo.com",
        "promos.biz",
        "company.com"
    ],
    "num_links": [5, 0, 7, 1, np.nan, 0, 4, 1],
    "num_words": [40, 120, 35, 80, 60, 100, 50, 90],
    "received_date": [
        "2024-01-15",
        "2024-01-18",
        "2024-02-02",
        "2024-02-10",
        "2024-03-05",
        "2024-03-08",
        "2024-03-20",
        "2024-04-01"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                         subject     label sender_domain  num_links  num_words  \
# 0           Win a free vacation      spam    promos.biz        5.0         40
# 1   Your receipt from Bookstore  not_spam     gmail.com        0.0        120
# 2            Limited time offer      spam   offers.mail        7.0         35
# 3                Meeting agenda  not_spam   company.com        1.0         80
# 4      Update your account info      spam   alerts.bank        NaN         60
# 5          Family photos inside  not_spam     yahoo.com        0.0        100
# 6  Exclusive promo just for you      spam    promos.biz        4.0         50
# 7         Weekly project status  not_spam   company.com        1.0         90
#
#   received_date
# 0    2024-01-15
# 1    2024-01-18
# 2    2024-02-02
# 3    2024-02-10
# 4    2024-03-05
# 5    2024-03-08
# 6    2024-03-20
# 7    2024-04-01

# %% [markdown]
# ## 1. Convert string labels to numeric

# %%
df['is_spam'] = df['label'].map({"spam": 1, "not_spam": 0})
df[['label', 'is_spam']]
# Out:
#       label  is_spam
# 0      spam        1
# 1  not_spam        0
# 2      spam        1
# 3  not_spam        0
# 4      spam        1
# 5  not_spam        0
# 6      spam        1
# 7  not_spam        0

# %% [markdown]
# ## 2. Create dummy variables for sender_domain

# %%
df = pd.get_dummies(df, columns=["sender_domain"], prefix="domain")
df.head()
# Out:
#                        subject     label  num_links  num_words received_date  \
# 0          Win a free vacation      spam        5.0         40    2024-01-15
# 1  Your receipt from Bookstore  not_spam        0.0        120    2024-01-18
# 2           Limited time offer      spam        7.0         35    2024-02-02
# 3               Meeting agenda  not_spam        1.0         80    2024-02-10
# 4     Update your account info      spam        NaN         60    2024-03-05
#
#    is_spam  domain_alerts.bank  domain_company.com  domain_gmail.com  \
# 0        1               False               False             False
# 1        0               False               False              True
# 2        1               False               False             False
# 3        0               False                True             False
# 4        1                True               False             False
#
#    domain_offers.mail  domain_promos.biz  domain_yahoo.com
# 0               False               True             False
# 1               False              False             False
# 2                True              False             False
# 3               False              False             False
# 4               False              False             False

# %% [markdown]
# ## 3. Handle missing numeric values

# %%
data = df.loc[3:5, ["num_links"]]
median_links = data.median()
data
# df["num_links"] = df["num_links"].fillna(median_links)
# df["num_links"]
# Out:
#    num_links
# 3  -0.562074
# 4  -0.562074
# 5  -0.970855

# %% [markdown]
# ## 4. Standard scale numeric features

# %%
scaler = sklearn.preprocessing.StandardScaler()
df["num_links_original"] = df["num_links"]
df["num_words_original"] = df["num_words"]

df[["num_links", "num_words"]] = scaler.fit_transform(df[["num_links", "num_words"]])
df[["num_links_original","num_links", "num_words_original", "num_words"]]
# Out:
#    num_links_original  num_links  num_words_original  num_words
# 0                 5.0   1.073050                  40  -1.118518
# 1                 0.0  -0.970855                 120   1.688743
# 2                 7.0   1.890612                  35  -1.293972
# 3                 1.0  -0.562074                  80   0.285112
# 4                 1.0  -0.562074                  60  -0.416703
# 5                 0.0  -0.970855                 100   0.986928
# 6                 4.0   0.664269                  50  -0.767610
# 7                 1.0  -0.562074                  90   0.636020

# %% [markdown]
# ## 5. Extract month from received_date

# %%
df["received_month"] = pd.to_datetime(df["received_date"]).dt.month
df[["received_date", "received_month"]]
# Out:
#   received_date  received_month
# 0    2024-01-15               1
# 1    2024-01-18               1
# 2    2024-02-02               2
# 3    2024-02-10               2
# 4    2024-03-05               3
# 5    2024-03-08               3
# 6    2024-03-20               3
# 7    2024-04-01               4

# %% [markdown]
# ## Final formatted DataFrame

# %%
df
# Out:
#                         subject     label  num_links  num_words received_date  \
# 0           Win a free vacation      spam   1.073050  -1.118518    2024-01-15
# 1   Your receipt from Bookstore  not_spam  -0.970855   1.688743    2024-01-18
# 2            Limited time offer      spam   1.890612  -1.293972    2024-02-02
# 3                Meeting agenda  not_spam  -0.562074   0.285112    2024-02-10
# 4      Update your account info      spam  -0.562074  -0.416703    2024-03-05
# 5          Family photos inside  not_spam  -0.970855   0.986928    2024-03-08
# 6  Exclusive promo just for you      spam   0.664269  -0.767610    2024-03-20
# 7         Weekly project status  not_spam  -0.562074   0.636020    2024-04-01
#
#    is_spam  domain_alerts.bank  domain_company.com  domain_gmail.com  \
# 0        1               False               False             False
# 1        0               False               False              True
# 2        1               False               False             False
# 3        0               False                True             False
# 4        1                True               False             False
# 5        0               False               False             False
# 6        1               False               False             False
# 7        0               False                True             False
#
#    domain_offers.mail  domain_promos.biz  domain_yahoo.com  \
# 0               False               True             False
# 1               False              False             False
# 2                True              False             False
# 3               False              False             False
# 4               False              False             False
# 5               False              False              True
# 6               False               True             False
# 7               False              False             False
#
#    num_links_original  num_words_original  received_month
# 0                 5.0                  40               1
# 1                 0.0                 120               1
# 2                 7.0                  35               2
# 3                 1.0                  80               2
# 4                 1.0                  60               3
# 5                 0.0                 100               3
# 6                 4.0                  50               3
# 7                 1.0                  90               4
